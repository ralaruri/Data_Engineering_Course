# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, datetime.time(0, 0, 57, 796000), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, datetime.time(0, 1, 30, 796000), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, datetime.time(0, 4, 1, 796000), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (4, datetime.time(0, 4, 55, 796000), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (5, datetime.time(0, 7, 13, 796000), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT count(distinct user_id), level FROM users group by level;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 2 rows affected.
# [(74, 'free'), (22, 'paid')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 150),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 76),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 291),
#  ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('AR8IEZO1187B99055E', 'Marc Shaiman', '', 'NaN', 'NaN'),
#  ('AR558FS1187FB45658', '40 Grit', '', 'NaN', 'NaN'),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', 'NaN', 'NaN'),
#  ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', '40.79086', '-73.96644'),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', '-13.442', '-41.9952')]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.time(0, 0, 57, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 1, 30, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 4, 1, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 4, 55, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 7, 13, 796000), 0, 29, 48, 11, 2018, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql SELECT * FROM time songplays limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.time(0, 0, 57, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 1, 30, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 4, 1, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 4, 55, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.time(0, 7, 13, 796000), 0, 29, 48, 11, 2018, 3)]

# %%
# %sql SELECT count(distinct user_id), level FROM users group by level;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 2 rows affected.
# [(74, 'free'), (22, 'paid')]

# %%
# %%sql
# with songplays as (select * from songplays),
#
# users as (select * from users),
#
# songs as (select * from songs),
#
# joined_users as (
#         select songplays.*, users.first_name, users.last_name, users.gender from songplays
#         left join users
#         ON songplays.user_id = users.user_id
# )
#
#
# select
#     distinct(user_id),
#     first_name,
#     last_name,
#     gender,
#     level,
#     count(songplay_id) as songplay_count
# from joined_users
# group by user_id, first_name, last_name, gender, level
# order by songplay_count desc;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 104 rows affected.
# [(49, 'Chloe', 'Cuevas', 'F', 'paid', 650),
#  (80, 'Tegan', 'Levine', 'F', 'paid', 648),
#  (97, 'Kate', 'Harrell', 'F', 'paid', 557),
#  (15, 'Lily', 'Koch', 'F', 'paid', 462),
#  (44, 'Aleena', 'Kirby', 'F', 'paid', 397),
#  (29, 'Jacqueline', 'Lynch', 'F', 'paid', 341),
#  (24, 'Layla', 'Griffin', 'F', 'paid', 321),
#  (73, 'Jacob', 'Klein', 'M', 'paid', 289),
#  (36, 'Matthew', 'Jones', 'M', 'paid', 241),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'paid', 241),
#  (95, 'Sara', 'Johnson', 'F', 'paid', 213),
#  (16, 'Rylan', 'George', 'M', 'paid', 208),
#  (30, 'Avery', 'Watkins', 'F', 'paid', 178),
#  (85, 'Kinsley', 'Young', 'F', 'paid', 178),
#  (25, 'Jayden', 'Graves', 'M', 'paid', 169),
#  (42, 'Harper', 'Barrett', 'M', 'paid', 140),
#  (58, 'Emily', 'Benson', 'F', 'paid', 140),
#  (26, 'Ryan', 'Smith', 'M', 'free', 114),
#  (82, 'Avery', 'Martinez', 'F', 'paid', 87),
#  (72, 'Hayden', 'Brock', 'F', 'paid', 72),
#  (32, 'Lily', 'Burns', 'F', 'free', 56),
#  (101, 'Jayden', 'Fox', 'M', 'free', 55),
#  (50, 'Ava', 'Robinson', 'F', 'free', 48),
#  (86, 'Aiden', 'Hess', 'M', 'free', 45),
#  (49, 'Chloe', 'Cuevas', 'F', 'free', 39),
#  (66, 'Kevin', 'Arellano', 'M', 'free', 37),
#  (37, 'Jordan', 'Hicks', 'F', 'free', 34),
#  (70, 'Jaleah', 'Hayes', 'F', 'paid', 33),
#  (69, 'Anabelle', 'Simpson', 'F', 'free', 29),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free', 29),
#  (10, 'Sylvie', 'Cruz', 'F', 'free', 28),
#  (8, 'Kaylee', 'Summers', 'F', 'free', 27),
#  (54, 'Kaleb', 'Cook', 'M', 'free', 27),
#  (83, 'Stefany', 'White', 'F', 'free', 27),
#  (92, 'Ryann', 'Smith', 'F', 'free', 27),
#  (67, 'Colm', 'Santana', 'M', 'free', 25),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free', 24),
#  (6, 'Cecilia', 'Owens', 'F', 'free', 23),
#  (14, 'Theodore', 'Harris', 'M', 'free', 22),
#  (33, 'Bronson', 'Harris', 'M', 'free', 20),
#  (53, 'Celeste', 'Williams', 'F', 'free', 20),
#  (63, 'Ayla', 'Johnson', 'F', 'free', 20),
#  (100, 'Adler', 'Barrera', 'M', 'free', 19),
#  (60, 'Devin', 'Larson', 'M', 'free', 18),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free', 18),
#  (52, 'Theodore', 'Smith', 'M', 'free', 17),
#  (65, 'Amiya', 'Davidson', 'F', 'paid', 17),
#  (80, 'Tegan', 'Levine', 'F', 'free', 17),
#  (9, 'Wyatt', 'Scott', 'M', 'free', 16),
#  (35, 'Molly', 'Taylor', 'F', 'free', 16),
#  (16, 'Rylan', 'George', 'M', 'free', 15),
#  (51, 'Maia', 'Burke', 'F', 'free', 15),
#  (55, 'Martin', 'Johnson', 'M', 'free', 15),
#  (76, 'Jayden', 'Duffy', 'F', 'free', 14),
#  (78, 'Chloe', 'Roth', 'F', 'free', 14),
#  (96, 'Cierra', 'Finley', 'F', 'free', 13),
#  (12, 'Austin', 'Rosales', 'M', 'free', 12),
#  (43, 'Jahiem', 'Miles', 'M', 'free', 11),
#  (2, 'Jizelle', 'Benjamin', 'F', 'free', 10),
#  (62, 'Connar', 'Moreno', 'M', 'free', 10),
#  (77, 'Magdalene', 'Herman', 'F', 'free', 10),
#  (89, 'Kynnedi', 'Sanchez', 'F', 'free', 10),
#  (19, 'Zachary', 'Thomas', 'M', 'free', 9),
#  (20, 'Aiden', 'Ramirez', 'M', 'paid', 9),
#  (34, 'Evelin', 'Ayala', 'F', 'free', 9),
#  (41, 'Brayden', 'Clark', 'M', 'free', 9),
#  (91, 'Jayden', 'Bell', 'M', 'free', 9),
#  (57, 'Katherine', 'Gay', 'F', 'free', 8),
#  (74, 'Braden', 'Parker', 'M', 'free', 8),
#  (17, 'Makinley', 'Jones', 'F', 'free', 7),
#  (28, 'Brantley', 'West', 'M', 'free', 7),
#  (36, 'Matthew', 'Jones', 'M', 'free', 7),
#  (40, 'Tucker', 'Garrison', 'M', 'free', 7),
#  (94, 'Noah', 'Chavez', 'M', 'free', 7),
#  (81, 'Sienna', 'Colon', 'F', 'free', 6),
#  (84, 'Shakira', 'Hunt', 'F', 'free', 6),
#  (4, 'Alivia', 'Terrell', 'F', 'free', 5),
#  (7, 'Adelyn', 'Jordan', 'F', 'free', 5),
#  (13, 'Ava', 'Robinson', 'F', 'free', 5),
#  (18, 'Jacob', 'Rogers', 'M', 'free', 5),
#  (29, 'Jacqueline', 'Lynch', 'F', 'free', 5),
#  (71, 'Ayleen', 'Wise', 'F', 'free', 5),
#  (5, 'Elijah', 'Davis', 'M', 'free', 4),
#  (23, 'Morris', 'Gilmore', 'M', 'free', 4),
#  (98, 'Jordyn', 'Powell', 'F', 'free', 4),
#  (99, 'Ann', 'Banks', 'F', 'free', 4),
#  (3, 'Isaac', 'Valdez', 'M', 'free', 3),
#  (38, 'Gianna', 'Jones', 'F', 'free', 3),
#  (47, 'Kimber', 'Norris', 'F', 'free', 3),
#  (48, 'Marina', 'Sutton', 'F', 'free', 3),
#  (68, 'Jordan', 'Rodriguez', 'F', 'free', 3),
#  (90, 'Andrea', 'Butler', 'F', 'free', 3),
#  (11, 'Christian', 'Porter', 'F', 'free', 2),
#  (22, 'Sean', 'Wilson', 'F', 'free', 2),
#  (27, 'Carlos', 'Carter', 'M', 'free', 2),
#  (39, 'Walter', 'Frye', 'M', 'free', 2),
#  (56, 'Cienna', 'Freeman', 'F', 'free', 2),
#  (59, 'Lily', 'Cooper', 'F', 'free', 2),
#  (64, 'Hannah', 'Calhoun', 'F', 'free', 2),
#  (79, 'James', 'Martin', 'M', 'free', 2),
#  (15, 'Lily', 'Koch', 'F', 'free', 1),
#  (45, 'Dominick', 'Norris', 'M', 'free', 1),
#  (85, 'Kinsley', 'Young', 'F', 'free', 1),
#  (87, 'Dustin', 'Lee', 'M', 'free', 1)]
